# %% [markdown]
# # Arrays

# %% [markdown]
# ### 1. Array module

# %%
import array

# %%
### creation
arr1 = array.array('i', [10, 20, 30, 20, 50])
print(arr1)
# Out:
# array('i', [10, 20, 30, 20, 50])

# %%
arr2 = array.array('i', [60, 70, 80])
print(arr2)
# Out:
# array('i', [60, 70, 80])

# %%
### access
arr1[2]
# Out:
# 30

# %%
arr1[3]
# Out:
# 20

# %%
### traversal
for element in arr1:
    print(element)
# Out:
# 10
# 20
# 30
# 20
# 50

# %%
for element in arr1:
    print(element, end= " ")
# Out:
# 10 20 30 20 50

# %%
### insertion
